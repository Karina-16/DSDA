# %% [markdown]
# # Hotel Data Scraping from Booking.com

# %% [markdown]
# ### Importing Libraries

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# ### Defining url of webpage

# %%
url="https://www.booking.com/searchresults.en-gb.html?label=gen173nr-1FCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQHoAQH4AQuIAgGoAgO4AoyGh7IGwAIB0gIkMTY4ZWQ1OGEtMjM4NC00YzZkLWE1ZmYtNTY2OTM4ZmI2MGVi2AIG4AIB&sid=da339d13a4baf4755f31d80f86a8e557&aid=304142&checkin=2024-05-16&checkout=2024-05-17&dest_id=-2092174&dest_type=city&group_adults=2&req_adults=2&no_rooms=1&group_children=0&req_children=0"

# %% [markdown]
# ### Defining a header to mimic a web browser when making the request

# %%
Headers = ({'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36'})

# %% [markdown]
# ### Sending requesting to the url

# %%
webpage=requests.get(url, headers=Headers)

# %%
webpage
# Out:
# <Response [200]>

# %% [markdown]
# ### Printing raw content

# %%
webpage.content
# Out:
# b'<!DOCTYPE html>\n<!--\nYou know you could be getting paid to poke around in our code?\nWe\'re hiring designers and developers to work in Amsterdam:\nhttps://careers.booking.com/\n-->\n<!-- wdot-802 -->\n<script type="text/javascript" nonce="ENVObRWYh2EtjAx">\ndocument.addEventListener(\'DOMContentLoaded\', function () {\n/**\n* provides the current user\'s cookie consent\n* in order to use it:\n* 1. inline privacy/cookieConsent.js in the page you need to use it.\n* please note that this library relies on window.PCM.isCountryNeedCookieBanner to be initialised\n* before using (calling getValue function) it\n* 2. in your js file:\n*\n* var privacyCookieConsent = B.require(\'privacyCookieConsent\');\n* var consent = privacyCookieConsent.getValue();\n*/\nB.define(\'privacyCookieConsent\', function () {\nvar consentGroupIsAllowed = {\nanalytical: \'C0002%3A1\',\nmarketing: \'C0004%3A1\'\n};\nvar optanonConsentCookieName = \'OptanonConsent\';\nvar optanonBoxClosedCookieName = \'OptanonAle
# ...

# %% [markdown]
# ### creating a BeautifulSoup object soup

# %%
soup=BeautifulSoup(webpage.text)

# %% [markdown]
# ### Printing soup

# %%
soup
# Out:
# <!DOCTYPE html>
# <!--
# You know you could be getting paid to poke around in our code?
# We're hiring designers and developers to work in Amsterdam:
# https://careers.booking.com/
# --><!-- wdot-802 --><html><head><script nonce="ENVObRWYh2EtjAx" type="text/javascript">
# document.addEventListener('DOMContentLoaded', function () {
# /**
# * provides the current user's cookie consent
# * in order to use it:
# * 1. inline privacy/cookieConsent.js in the page you need to use it.
# * please note that this library relies on window.PCM.isCountryNeedCookieBanner to be initialised
# * before using (calling getValue function) it
# * 2. in your js file:
# *
# * var privacyCookieConsent = B.require('privacyCookieConsent');
# * var consent = privacyCookieConsent.getValue();
# */
# B.define('privacyCookieConsent', function () {
# var consentGroupIsAllowed = {
# analytical: 'C0002%3A1',
# marketing: 'C0004%3A1'
# };
# var optanonConsentCookieName = 'OptanonConsent';
# ...

# %% [markdown]
# ### Finding div tags containing hotels name

# %%
Hotel_names= soup.find_all('div', class_="f6431b446c a15b38c233")

# %%
Hotel_names
# Out:
# [<div class="f6431b446c a15b38c233" data-testid="title">Trident Bandra Kurla</div>,
#  <div class="f6431b446c a15b38c233" data-testid="title">Trident Nariman Point</div>,
#  <div class="f6431b446c a15b38c233" data-testid="title">Taj Lands End</div>,
#  <div class="f6431b446c a15b38c233" data-testid="title">Fairfield by Marriott Mumbai International Airport</div>,
#  <div class="f6431b446c a15b38c233" data-testid="title">Hotel BKC Annex</div>,
#  <div class="f6431b446c a15b38c233" data-testid="title">The Taj Mahal Tower, Mumbai</div>,
#  <div class="f6431b446c a15b38c233" data-testid="title">ITC Grand Central, a Luxury Collection Hotel, Mumbai</div>,
#  <div class="f6431b446c a15b38c233" data-testid="title">Taj Santacruz</div>,
#  <div class="f6431b446c a15b38c233" data-testid="title">JW Marriott Mumbai Juhu</div>,
#  <div class="f6431b446c a15b38c233" data-testid="title">The St. Regis Mumbai</div>,
#  <div class="f6431b446c a15b38c233" data-testid="title">The Leela Mumbai</div>,
# ...

# %% [markdown]
# ### Creating empty list and appending text from div tag in empty list

# %%
Hotels=[]

for i in Hotel_names:
    x=(i.text)
    Hotels.append(x)

# %%
Hotels
# Out:
# ['Trident Bandra Kurla',
#  'Trident Nariman Point',
#  'Taj Lands End',
#  'Fairfield by Marriott Mumbai International Airport',
#  'Hotel BKC Annex',
#  'The Taj Mahal Tower, Mumbai',
#  'ITC Grand Central, a Luxury Collection Hotel, Mumbai',
#  'Taj Santacruz',
#  'JW Marriott Mumbai Juhu',
#  'The St. Regis Mumbai',
#  'The Leela Mumbai',
#  'Four Seasons Hotel Mumbai',
#  'Grand Hyatt Mumbai Hotel and Residences',
#  'JW Marriott Mumbai Sahar Airport',
#  'Residency Hotel Fort',
#  'Sofitel Mumbai BKC',
#  'Radisson Mumbai Andheri MIDC',
#  'Holiday Inn Mumbai International Airport, an IHG Hotel',
#  'FabHotel Royal Mumbai International Airport',
#  'Residency Sarovar Portico',
#  'Hotel Marine Plaza',
#  'President - IHCL SeleQtions',
#  'ITC Maratha, a Luxury Collection Hotel, Mumbai',
#  'Hotel Ariana Residency',
#  'Hotel New Blue Sapphire Residency']

# %% [markdown]
# ### Finding div tags containing Ratings of the hotel

# %%
Rate=soup.find_all("div", class_="a3b8729ab1 d86cee9b25")

# %%
Rate
# Out:
# [<div class="a3b8729ab1 d86cee9b25">8.8<div class="ac4a7896c7">Scored 8.8 </div></div>,
#  <div class="a3b8729ab1 d86cee9b25">8.7<div class="ac4a7896c7">Scored 8.7 </div></div>,
#  <div class="a3b8729ab1 d86cee9b25">8.6<div class="ac4a7896c7">Scored 8.6 </div></div>,
#  <div class="a3b8729ab1 d86cee9b25">8.2<div class="ac4a7896c7">Scored 8.2 </div></div>,
#  <div class="a3b8729ab1 d86cee9b25">7.9<div class="ac4a7896c7">Scored 7.9 </div></div>,
#  <div class="a3b8729ab1 d86cee9b25">9.1<div class="ac4a7896c7">Scored 9.1 </div></div>,
#  <div class="a3b8729ab1 d86cee9b25">8.6<div class="ac4a7896c7">Scored 8.6 </div></div>,
#  <div class="a3b8729ab1 d86cee9b25">8.8<div class="ac4a7896c7">Scored 8.8 </div></div>,
#  <div class="a3b8729ab1 d86cee9b25">8.5<div class="ac4a7896c7">Scored 8.5 </div></div>,
#  <div class="a3b8729ab1 d86cee9b25">8.8<div class="ac4a7896c7">Scored 8.8 </div></div>,
#  <div class="a3b8729ab1 d86cee9b25">8.6<div class="ac4a7896c7">Scored 8.6 </div></div>,
# ...

# %% [markdown]
# ### Creating empty list and appending text from div tag in empty list

# %%
Ratings=[]

for i in Rate:
    x=(i.text)
    Ratings.append(x)

# %%
Ratings
# Out:
# ['8.8Scored 8.8 ',
#  '8.7Scored 8.7 ',
#  '8.6Scored 8.6 ',
#  '8.2Scored 8.2 ',
#  '7.9Scored 7.9 ',
#  '9.1Scored 9.1 ',
#  '8.6Scored 8.6 ',
#  '8.8Scored 8.8 ',
#  '8.5Scored 8.5 ',
#  '8.8Scored 8.8 ',
#  '8.6Scored 8.6 ',
#  '8.5Scored 8.5 ',
#  '8.0Scored 8.0 ',
#  '8.6Scored 8.6 ',
#  '8.4Scored 8.4 ',
#  '8.1Scored 8.1 ',
#  '8.2Scored 8.2 ',
#  '7.9Scored 7.9 ',
#  '7.4Scored 7.4 ',
#  '6.9Scored 6.9 ',
#  '7.6Scored 7.6 ',
#  '8.2Scored 8.2 ',
#  '8.1Scored 8.1 ',
#  '7.0Scored 7.0 ',
#  '8.6Scored 8.6 ']

# %% [markdown]
# ### Splitting each element from the list and extracting data

# %%
Rating=[]
for i in Ratings:
    x=(i.split())
    Rating.append(x[1])

# %%
Rating
# Out:
# ['8.8',
#  '8.7',
#  '8.6',
#  '8.2',
#  '7.9',
#  '9.1',
#  '8.6',
#  '8.8',
#  '8.5',
#  '8.8',
#  '8.6',
#  '8.5',
#  '8.0',
#  '8.6',
#  '8.4',
#  '8.1',
#  '8.2',
#  '7.9',
#  '7.4',
#  '6.9',
#  '7.6',
#  '8.2',
#  '8.1',
#  '7.0',
#  '8.6']

# %% [markdown]
# ### Finding div tags containing NO. of reviews

# %%
REviewNO=soup.find_all("div", class_="abf093bdfe f45d8e4c32 d935416c47")

# %%
REviewNO
# Out:
# [<div class="abf093bdfe f45d8e4c32 d935416c47">3,701 reviews</div>,
#  <div class="abf093bdfe f45d8e4c32 d935416c47">4,300 reviews</div>,
#  <div class="abf093bdfe f45d8e4c32 d935416c47">3,531 reviews</div>,
#  <div class="abf093bdfe f45d8e4c32 d935416c47">1,275 reviews</div>,
#  <div class="abf093bdfe f45d8e4c32 d935416c47">144 reviews</div>,
#  <div class="abf093bdfe f45d8e4c32 d935416c47">5,062 reviews</div>,
#  <div class="abf093bdfe f45d8e4c32 d935416c47">1,670 reviews</div>,
#  <div class="abf093bdfe f45d8e4c32 d935416c47">3,453 reviews</div>,
#  <div class="abf093bdfe f45d8e4c32 d935416c47">1,907 reviews</div>,
#  <div class="abf093bdfe f45d8e4c32 d935416c47">1,583 reviews</div>,
#  <div class="abf093bdfe f45d8e4c32 d935416c47">3,716 reviews</div>,
#  <div class="abf093bdfe f45d8e4c32 d935416c47">1,992 reviews</div>,
#  <div class="abf093bdfe f45d8e4c32 d935416c47">1,976 reviews</div>,
#  <div class="abf093bdfe f45d8e4c32 d935416c47">2,864 reviews</div>,
# ...

# %% [markdown]
# ### Creating empty list and appending text from div tag in empty list

# %%
Review_numbers=[]

for i in REviewNO:
    x=(i.text)
    Review_numbers.append(x)

# %%
Review_numbers
# Out:
# ['3,701 reviews',
#  '4,300 reviews',
#  '3,531 reviews',
#  '1,275 reviews',
#  '144 reviews',
#  '5,062 reviews',
#  '1,670 reviews',
#  '3,453 reviews',
#  '1,907 reviews',
#  '1,583 reviews',
#  '3,716 reviews',
#  '1,992 reviews',
#  '1,976 reviews',
#  '2,864 reviews',
#  '2,251 reviews',
#  '2,639 reviews',
#  '1,522 reviews',
#  '1,826 reviews',
#  '334 reviews',
#  '553 reviews',
#  '551 reviews',
#  '1,933 reviews',
#  '2,561 reviews',
#  '520 reviews',
#  '223 reviews']

# %% [markdown]
# ### Finding span tags containing location of the hotels

# %%
LOC=soup.find_all("span", class_="aee5343fdb def9bc142a")

# %%
LOC
# Out:
# [<span class="aee5343fdb def9bc142a" data-testid="address">Bandra, Mumbai</span>,
#  <span class="aee5343fdb def9bc142a">Show on map</span>,
#  <span class="aee5343fdb def9bc142a" data-testid="address">South Mumbai, Mumbai</span>,
#  <span class="aee5343fdb def9bc142a">Show on map</span>,
#  <span class="aee5343fdb def9bc142a" data-testid="address">Bandra, Mumbai</span>,
#  <span class="aee5343fdb def9bc142a">Show on map</span>,
#  <span class="aee5343fdb def9bc142a" data-testid="address">Western Suburbs, Mumbai</span>,
#  <span class="aee5343fdb def9bc142a">Show on map</span>,
#  <span class="aee5343fdb def9bc142a" data-testid="address">Bandra Kurla Complex, Mumbai</span>,
#  <span class="aee5343fdb def9bc142a">Show on map</span>,
#  <span class="aee5343fdb def9bc142a" data-testid="address">Colaba, Mumbai</span>,
#  <span class="aee5343fdb def9bc142a">Show on map</span>,
#  <span class="aee5343fdb def9bc142a" data-testid="address">South Mumbai, Mumbai</span>,
# ...

# %% [markdown]
# ### Creating empty list and appending text from div tag in empty list

# %%
Location=[]

for i in LOC:
    x=(i.text)
    Location.append(x)

# %%
Location
# Out:
# ['Bandra, Mumbai',
#  'Show on map',
#  'South Mumbai, Mumbai',
#  'Show on map',
#  'Bandra, Mumbai',
#  'Show on map',
#  'Western Suburbs, Mumbai',
#  'Show on map',
#  'Bandra Kurla Complex, Mumbai',
#  'Show on map',
#  'Colaba, Mumbai',
#  'Show on map',
#  'South Mumbai, Mumbai',
#  'Show on map',
#  'Mumbai',
#  'Show on map',
#  'Juhu, Mumbai',
#  'Show on map',
#  'Worli, Mumbai',
#  'Show on map',
#  'Western Suburbs, Mumbai',
#  'Show on map',
#  'Worli, Mumbai',
#  'Show on map',
#  'Santacruz, Mumbai',
#  'Show on map',
#  'Western Suburbs, Mumbai',
#  'Show on map',
#  'South Mumbai, Mumbai',
#  'Show on map',
#  'Bandra, Mumbai',
#  'Show on map',
#  'Western Suburbs, Mumbai',
#  'Show on map',
#  'Western Suburbs, Mumbai',
#  'Show on map',
#  'Western Suburbs, Mumbai',
#  'Show on map',
#  'Western Suburbs, Mumbai',
#  'Show on map',
#  'Churchgate, Mumbai',
#  'Show on map',
#  'South Mumbai, Mumbai',
#  'Show on map',
#  'Western Suburbs, Mumbai',
# ...

# %% [markdown]
# ### Slicing the list to get the locations

# %%
Location=Location[::2]

# %%
Location
# Out:
# ['Bandra, Mumbai',
#  'South Mumbai, Mumbai',
#  'Bandra, Mumbai',
#  'Western Suburbs, Mumbai',
#  'Bandra Kurla Complex, Mumbai',
#  'Colaba, Mumbai',
#  'South Mumbai, Mumbai',
#  'Mumbai',
#  'Juhu, Mumbai',
#  'Worli, Mumbai',
#  'Western Suburbs, Mumbai',
#  'Worli, Mumbai',
#  'Santacruz, Mumbai',
#  'Western Suburbs, Mumbai',
#  'South Mumbai, Mumbai',
#  'Bandra, Mumbai',
#  'Western Suburbs, Mumbai',
#  'Western Suburbs, Mumbai',
#  'Western Suburbs, Mumbai',
#  'Western Suburbs, Mumbai',
#  'Churchgate, Mumbai',
#  'South Mumbai, Mumbai',
#  'Western Suburbs, Mumbai',
#  'Western Suburbs, Mumbai',
#  'Western Suburbs, Mumbai']

# %% [markdown]
# ### Creating dictionary

# %%
data={"Hotel":Hotels, "Rating":Rating, "Location":Location, "Review_numbers":Review_numbers}

# %% [markdown]
# ### Converting dictionary into dataframe

# %%
df=pd.DataFrame(data)
df.to_csv("Scrap_data.csv")

# %% [markdown]
# ### Printing the scraped data

# %%
df
# Out:
#                                                 Hotel Rating  \
# 0                                Trident Bandra Kurla    8.8
# 1                               Trident Nariman Point    8.7
# 2                                       Taj Lands End    8.6
# 3   Fairfield by Marriott Mumbai International Air...    8.2
# 4                                     Hotel BKC Annex    7.9
# 5                         The Taj Mahal Tower, Mumbai    9.1
# 6   ITC Grand Central, a Luxury Collection Hotel, ...    8.6
# 7                                       Taj Santacruz    8.8
# 8                             JW Marriott Mumbai Juhu    8.5
# 9                                The St. Regis Mumbai    8.8
# 10                                   The Leela Mumbai    8.6
# 11                          Four Seasons Hotel Mumbai    8.5
# 12            Grand Hyatt Mumbai Hotel and Residences    8.0
# 13                   JW Marriott Mumbai Sahar Airport    8.6
# ...
